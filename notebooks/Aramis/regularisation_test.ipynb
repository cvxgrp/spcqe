# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from spcqe.functions import make_regularization_matrix

# %%
num_harmonics = 3
weight = 1
periods = 24

reg_ref = make_regularization_matrix(
    num_harmonics,
    weight,
    periods,
    standing_wave=False,
    trend=True
)

sns.heatmap(reg_ref.toarray(), cmap='viridis');

# %%
num_harmonics = 3
weight = 1
periods = 24

reg_ref = make_regularization_matrix(
    num_harmonics,
    weight,
    periods,
    standing_wave=True,
    trend=False
)

sns.heatmap(reg_ref.toarray(), cmap='viridis');
