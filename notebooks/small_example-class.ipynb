# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from spcqe.quantiles import SmoothPeriodicQuantiles

# %%
def process_excel_file(file_name, year):
    # Check if the year is a leap year
    is_leap_year = (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)
    
    # Define the start and end of your time range
    start = pd.Timestamp(f'{year}-01-01 00:00:00')
    end = pd.Timestamp(f'{year}-12-31 23:00:00')
    
    # Create an hourly time index between start and end
    time_index = pd.date_range(start, end, freq='H')
    
    # Read the Excel file and select columns
    df = pd.read_excel(file_name, sheet_name='RI', usecols=['RT_Demand', 'Dry_Bulb', 'RT_LMP'])
    
    # Assign your new time index to your dataframe
    df.index = time_index
    
    return df

years = [2019, 2020, 2021, 2022]
paths = [Path() / 'fixtures' / f'{year}_smd_hourly.xlsx' for year in years]
df_list = [process_excel_file(path, year) for (path, year) in zip(paths, years)]

df = pd.concat(df_list)
df
# Out:
#                      RT_Demand  RT_LMP  Dry_Bulb
# 2019-01-01 00:00:00    723.322   35.90        42
# 2019-01-01 01:00:00    688.771   38.81        44
# 2019-01-01 02:00:00    660.226   21.32        44
# 2019-01-01 03:00:00    642.773   18.52        46
# 2019-01-01 04:00:00    638.376    7.57        49
# ...                        ...     ...       ...
# 2022-12-31 19:00:00    876.594   26.33        49
# 2022-12-31 20:00:00    832.016   25.35        50
# 2022-12-31 21:00:00    793.269   31.66        49
# 2022-12-31 22:00:00    755.760   44.33        48
# 2022-12-31 23:00:00    713.978   58.98        47
#
# [35064 rows x 3 columns]

# %%
ix = 100
data_view = df.iloc[24 * ix:24 * (ix + 30)]
plt.plot(data_view)
plt.xticks(rotation=45);

# %%
y1 = data_view['RT_Demand']
P2 = int(7*24)
P3 = int(24)
K = 3
l = 0.1
spq = SmoothPeriodicQuantiles(K, [P2, P3], weight=l, verbose=True)
spq
# Out:
# SmoothPeriodicQuantiles(num_harmonics=3, periods=[168, 24], verbose=True,
#                         weight=0.1)

# %%
spq.fit(y1)
print(f"total time: {spq.fit_time:.2f} seconds")
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Aug 24 12:09:55 AM: Your problem has 550 variables, 1 constraints, and 0 parameters.
# (CVXPY) Aug 24 12:09:55 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 24 12:09:55 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 24 12:09:55 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 24 12:09:55 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 24 12:09:55 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 24 12:09:55 AM: Applying reduction Dcp2Cone
# (CVXPY) Aug 24 12:09:55 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 24 12:09:55 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 24 12:09:56 AM: Applying reduction MOSEK
# (CVXPY) Aug 24 12:09:56 AM: Finished problem compilation (took 4.934e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 24 12:09:56 AM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Aug 24 12:09:56 AM: MOSEK warning 500 (MSK_RES_WRN_LICENSE_EXPIRE): The license expires in 2 days.
# (CVXPY) Aug 24 12:09:56 AM: MOSEK warning 500 (MSK_RES_WRN_LICENSE_EXPIRE): The license expires in 2 days.
# (CVXPY) Aug 24 12:09:56 AM: Problem
# (CVXPY) Aug 24 12:09:56 AM:   Name                   :
# (CVXPY) Aug 24 12:09:56 AM:   Objective sense        : maximize
# (CVXPY) Aug 24 12:09:56 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 24 12:09:56 AM:   Constraints            : 8471
# (CVXPY) Aug 24 12:09:56 AM:   Affine conic cons.     : 0
# (CVXPY) Aug 24 12:09:56 AM:   Disjunctive cons.      : 0
# (CVXPY) Aug 24 12:09:56 AM:   Cones                  : 1
# (CVXPY) Aug 24 12:09:56 AM:   Scalar variables       : 23592
# (CVXPY) Aug 24 12:09:56 AM:   Matrix variables       : 0
# (CVXPY) Aug 24 12:09:56 AM:   Integer variables      : 0
# (CVXPY) Aug 24 12:09:56 AM:
# (CVXPY) Aug 24 12:09:56 AM: Optimizer started.
# (CVXPY) Aug 24 12:09:56 AM: Presolve started.
# (CVXPY) Aug 24 12:09:56 AM: Linear dependency checker started.
# (CVXPY) Aug 24 12:09:56 AM: Linear dependency checker terminated.
# (CVXPY) Aug 24 12:09:56 AM: Eliminator started.
# (CVXPY) Aug 24 12:09:56 AM: Freed constraints in eliminator : 7920
# (CVXPY) Aug 24 12:09:56 AM: Eliminator terminated.
# (CVXPY) Aug 24 12:09:56 AM: Eliminator started.
# (CVXPY) Aug 24 12:09:56 AM: Freed constraints in eliminator : 0
# (CVXPY) Aug 24 12:09:56 AM: Eliminator terminated.
# (CVXPY) Aug 24 12:09:56 AM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Aug 24 12:09:56 AM: Lin. dep.  - tries                  : 1                 time                   : 0.01
# (CVXPY) Aug 24 12:09:56 AM: Lin. dep.  - primal attempts        : 1                 successes              : 1
# (CVXPY) Aug 24 12:09:56 AM: Lin. dep.  - dual attempts          : 0                 successes              : 0
# (CVXPY) Aug 24 12:09:56 AM: Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# (CVXPY) Aug 24 12:09:56 AM: Presolve terminated. Time: 0.12
# (CVXPY) Aug 24 12:09:56 AM: GP based matrix reordering started.
# (CVXPY) Aug 24 12:09:56 AM: GP based matrix reordering terminated.
# (CVXPY) Aug 24 12:09:56 AM: Optimizer  - threads                : 12
# (CVXPY) Aug 24 12:09:56 AM: Optimizer  - solved problem         :
# (CVXPY) Aug 24 12:09:56 AM: the primal
# (CVXPY) Aug 24 12:09:56 AM:
# (CVXPY) Aug 24 12:09:56 AM: Optimizer  - Constraints            : 551
# (CVXPY) Aug 24 12:09:56 AM: Optimizer  - Cones                  : 1
# (CVXPY) Aug 24 12:09:56 AM: Optimizer  - Scalar variables       : 15650             conic                  : 530
# (CVXPY) Aug 24 12:09:56 AM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Aug 24 12:09:56 AM: Factor     - setup time             : 0.06
# (CVXPY) Aug 24 12:09:56 AM: Factor     - dense det. time        : 0.03              GP order time          : 0.00
# (CVXPY) Aug 24 12:09:56 AM: Factor     - nonzeros before factor : 1.43e+05          after factor           : 1.52e+05
# (CVXPY) Aug 24 12:09:56 AM: Factor     - dense dim.             : 0                 flops                  : 1.25e+08
# (CVXPY) Aug 24 12:09:56 AM: Factor     - GP saved nzs           : -1044             GP saved flops         : 6.75e+07
# (CVXPY) Aug 24 12:09:56 AM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Aug 24 12:09:57 AM: 18  1.1e-03  2.2e-02  6.9e-07  9.83e-01   4.653744768e+04   4.653744494e+04   6.3e-06  0.48
# (CVXPY) Aug 24 12:09:57 AM: 19  7.8e-04  1.5e-02  4.1e-07  9.96e-01   4.665678268e+04   4.665678076e+04   4.4e-06  0.49
# (CVXPY) Aug 24 12:09:57 AM: 20  1.5e-04  3.0e-03  3.6e-08  9.97e-01   4.687961443e+04   4.687961404e+04   8.7e-07  0.51
# (CVXPY) Aug 24 12:09:57 AM: 21  8.6e-05  1.7e-03  1.5e-08  9.99e-01   4.690369401e+04   4.690369379e+04   4.9e-07  0.52
# (CVXPY) Aug 24 12:09:57 AM: 22  1.4e-05  2.8e-04  1.1e-09  1.00e+00   4.692948879e+04   4.692948876e+04   8.2e-08  0.54
# (CVXPY) Aug 24 12:09:57 AM: 23  2.1e-06  4.0e-05  1.2e-10  1.00e+00   4.693391051e+04   4.693391051e+04   1.2e-08  0.55
# (CVXPY) Aug 24 12:09:57 AM: 24  4.6e-07  8.9e-06  5.8e-10  1.00e+00   4.693449041e+04   4.693449042e+04   2.6e-09  0.56
# (CVXPY) Aug 24 12:09:57 AM: 25  6.4e-08  1.5e-06  7.4e-11  1.00e+00   4.693463165e+04   4.693463165e+04   3.6e-10  0.59
# (CVXPY) Aug 24 12:09:57 AM: Optimizer terminated. Time: 0.60
# (CVXPY) Aug 24 12:09:57 AM:
# (CVXPY) Aug 24 12:09:57 AM: Interior-point solution summary
# (CVXPY) Aug 24 12:09:57 AM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Aug 24 12:09:57 AM:   Solution status : OPTIMAL
# (CVXPY) Aug 24 12:09:57 AM:   Primal.  obj: 4.6934631647e+04    nrm: 3e+03    Viol.
# (CVXPY) Aug 24 12:09:57 AM:   con: 6e-06
# (CVXPY) Aug 24 12:09:57 AM:   var: 3e-08
# (CVXPY) Aug 24 12:09:57 AM:   cones: 0e+00
# (CVXPY) Aug 24 12:09:57 AM:
# (CVXPY) Aug 24 12:09:57 AM:   Dual.    obj: 4.6934631651e+04    nrm: 5e+03    Viol.
# (CVXPY) Aug 24 12:09:57 AM:   con: 0e+00
# (CVXPY) Aug 24 12:09:57 AM:   var: 3e-05
# (CVXPY) Aug 24 12:09:57 AM:   cones: 0e+00
# (CVXPY) Aug 24 12:09:57 AM:
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 24 12:09:57 AM: Problem status: optimal
# (CVXPY) Aug 24 12:09:57 AM: Optimal value: 4.693e+04
# (CVXPY) Aug 24 12:09:57 AM: Compilation took 4.934e-01 seconds
# (CVXPY) Aug 24 12:09:57 AM: Solver (including time spent in interface) took 8.838e-01 seconds
# total time: 1.40 seconds

# %%
ix = 0
slc = np.s_[24 * ix:24 * (ix + 10)]
xs = df.index[slc]
plt.plot(xs, y1[slc], ls='--')
plt.plot(xs, spq.quantiles[slc, :], alpha=0.5)
plt.xticks(rotation=45);

# %%
ix = 7
slc = np.s_[24 * ix:24 * (ix + 10)]
xs = df.index[slc]
plt.plot(xs, y1[slc], ls='--')
plt.plot(xs, spq.quantiles[slc, :], alpha=0.5)
plt.xticks(rotation=45);
