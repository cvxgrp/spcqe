# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from spcqe.quantiles import SmoothPeriodicQuantiles

# %%
def process_excel_file(file_name, year):
    # Check if the year is a leap year
    is_leap_year = (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)
    
    # Define the start and end of your time range
    start = pd.Timestamp(f'{year}-01-01 00:00:00')
    end = pd.Timestamp(f'{year}-12-31 23:00:00')
    
    # Create an hourly time index between start and end
    time_index = pd.date_range(start, end, freq='H')
    
    # Read the Excel file and select columns
    df = pd.read_excel(file_name, sheet_name='RI', usecols=['RT_Demand', 'Dry_Bulb', 'RT_LMP'])
    
    # Assign your new time index to your dataframe
    df.index = time_index
    
    return df

years = [2019, 2020, 2021, 2022]
paths = [Path() / 'fixtures' / f'{year}_smd_hourly.xlsx' for year in years]
df_list = [process_excel_file(path, year) for (path, year) in zip(paths, years)]

df = pd.concat(df_list)
df
# Out:
#                      RT_Demand  RT_LMP  Dry_Bulb
# 2019-01-01 00:00:00    723.322   35.90        42
# 2019-01-01 01:00:00    688.771   38.81        44
# 2019-01-01 02:00:00    660.226   21.32        44
# 2019-01-01 03:00:00    642.773   18.52        46
# 2019-01-01 04:00:00    638.376    7.57        49
# ...                        ...     ...       ...
# 2022-12-31 19:00:00    876.594   26.33        49
# 2022-12-31 20:00:00    832.016   25.35        50
# 2022-12-31 21:00:00    793.269   31.66        49
# 2022-12-31 22:00:00    755.760   44.33        48
# 2022-12-31 23:00:00    713.978   58.98        47
#
# [35064 rows x 3 columns]

# %%
ix = 100
data_view = df.iloc[24 * ix:24 * (ix + 30)]
plt.plot(data_view)
plt.xticks(rotation=45);

# %%
P1 = int(365*24)
P2 = int(7*24)
P3 = int(24)
K = 3
l = 0.1
spq = SmoothPeriodicQuantiles(K, [P1, P2, P3], quantiles=.5, weight=l, verbose=True, solver='OSQP')
spq
# Out:
# SmoothPeriodicQuantiles(num_harmonics=3, periods=[8760, 168, 24],
#                         quantiles=array([0.5]), solver='OSQP', verbose=True,
#                         weight=0.1)

# %%
y1 = df['RT_Demand']
spq.fit(y1)
print(f"total time: {spq.fit_time:.2f} seconds")
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Aug 24 11:23:06 AM: Your problem has 128 variables, 0 constraints, and 0 parameters.
# (CVXPY) Aug 24 11:23:06 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 24 11:23:06 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 24 11:23:06 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 24 11:23:06 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Aug 24 11:23:06 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Aug 24 11:23:06 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 24 11:23:06 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Aug 24 11:23:06 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Aug 24 11:23:07 AM: Applying reduction OSQP
# (CVXPY) Aug 24 11:23:08 AM: Finished problem compilation (took 2.022e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 24 11:23:08 AM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 35320, constraints m = 70256
#           nnz(P) + nnz(A) = 9046714
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1  
# 6600   1.0769e+06   3.42e-02   5.15e-04   8.34e-04   1.33e+02s
# 6800   1.0769e+06   3.33e-02   3.25e-04   8.34e-04   1.36e+02s
# 7000   1.0769e+06   3.34e-02   9.35e-05   8.34e-04   1.40e+02s
# 7200   1.0769e+06   3.73e-02   2.33e-04   8.34e-04   1.44e+02s
# 7400   1.0769e+06   3.64e-02   1.25e-04   8.34e-04   1.48e+02s
# 7600   1.0769e+06   3.57e-02   1.70e-04   8.34e-04   1.52e+02s
# 7800   1.0769e+06   3.64e-02   6.30e-05   8.34e-04   1.56e+02s
# 8000   1.0769e+06   3.65e-02   2.54e-04   8.34e-04   1.59e+02s
# 8200   1.0769e+06   3.65e-02   1.58e-04   8.34e-04   1.63e+02s
# 8400   1.0769e+06   3.37e-02   4.31e-04   8.34e-04   1.67e+02s
# 8600   1.0769e+06   3.47e-02   1.39e-04   8.34e-04   1.71e+02s
# 8800   1.0769e+06   3.30e-02   1.60e-04   8.34e-04   1.75e+02s
# 9000   1.0769e+06   3.11e-02   3.44e-04   8.34e-04   1.79e+02s
# 9200   1.0769e+06   2.12e-02   8.35e-04   8.34e-04   1.82e+02s
# 9400   1.0769e+06   2.55e-02   3.63e-04   8.34e-04   1.86e+02s
# 9600   1.0769e+06   2.40e-02   1.53e-04   8.34e-04   1.90e+02s
# 9800   1.0769e+06   1.89e-02   3.43e-04   8.34e-04   1.94e+02s
# 10000   1.0769e+06   1.91e-02   2.60e-04   8.34e-04   1.98e+02s
#
# status:               solved inaccurate
# number of iterations: 10000
# optimal objective:    1076854.4771
# run time:             1.98e+02s
# optimal rho estimate: 6.33e-04
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 24 11:26:26 AM: Problem status: optimal_inaccurate
# (CVXPY) Aug 24 11:26:26 AM: Optimal value: 1.077e+06
# (CVXPY) Aug 24 11:26:26 AM: Compilation took 2.022e+00 seconds
# (CVXPY) Aug 24 11:26:26 AM: Solver (including time spent in interface) took 1.979e+02 seconds
# total time: 200.02 seconds
# /Users/bennetm/miniconda3/envs/spcqe-dev/lib/python3.10/site-packages/cvxpy/problems/problem.py:1387: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %%
ix = 0
slc = np.s_[24 * ix:24 * (ix + 10)]
xs = df.index[slc]
plt.plot(xs, y1[slc], ls='--')
plt.plot(xs, spq.fit_quantiles[slc, :], alpha=0.5)
plt.xticks(rotation=45);

# %%
ix = 200
slc = np.s_[24 * ix:24 * (ix + 10)]
xs = df.index[slc]
plt.plot(xs, y1[slc], ls='--')
plt.plot(xs, spq.fit_quantiles[slc, :], alpha=0.5)
plt.xticks(rotation=45);

# %%
ix = 150
slc = np.s_[24 * ix:24 * (ix + 10)]
xs = df.index[slc]
saved_quantiles = np.loadtxt('quantiles_saved.txt')
plt.plot(xs, saved_quantiles[slc, 5], label='full fit')
plt.plot(xs, spq.fit_quantiles[slc, :], label='single fit')
plt.legend()
plt.title(f"{spq.quantiles[0]*100:.0f}th percentile fit")
plt.xticks(rotation=45);
