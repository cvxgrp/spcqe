# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from spcqe.quantiles import SmoothPeriodicQuantiles

# %%
def process_excel_file(file_name, year):
    # Check if the year is a leap year
    is_leap_year = (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)
    
    # Define the start and end of your time range
    start = pd.Timestamp(f'{year}-01-01 00:00:00')
    end = pd.Timestamp(f'{year}-12-31 23:00:00')
    
    # Create an hourly time index between start and end
    time_index = pd.date_range(start, end, freq='H')
    
    # Read the Excel file and select columns
    df = pd.read_excel(file_name, sheet_name='RI', usecols=['RT_Demand', 'Dry_Bulb', 'RT_LMP'])
    
    # Assign your new time index to your dataframe
    df.index = time_index
    
    return df

years = [2019, 2020, 2021, 2022]
paths = [Path() / 'fixtures' / f'{year}_smd_hourly.xlsx' for year in years]
df_list = [process_excel_file(path, year) for (path, year) in zip(paths, years)]

df = pd.concat(df_list)
df
# Out:
#                      RT_Demand  RT_LMP  Dry_Bulb
# 2019-01-01 00:00:00    723.322   35.90        42
# 2019-01-01 01:00:00    688.771   38.81        44
# 2019-01-01 02:00:00    660.226   21.32        44
# 2019-01-01 03:00:00    642.773   18.52        46
# 2019-01-01 04:00:00    638.376    7.57        49
# ...                        ...     ...       ...
# 2022-12-31 19:00:00    876.594   26.33        49
# 2022-12-31 20:00:00    832.016   25.35        50
# 2022-12-31 21:00:00    793.269   31.66        49
# 2022-12-31 22:00:00    755.760   44.33        48
# 2022-12-31 23:00:00    713.978   58.98        47
#
# [35064 rows x 3 columns]

# %%
ix = 100
data_view = df.iloc[24 * ix:24 * (ix + 30)]
plt.plot(data_view)
plt.xticks(rotation=45);

# %%
P1 = int(365*24)
P2 = int(7*24)
P3 = int(24)
K = 3
l = 0.1
spq = SmoothPeriodicQuantiles(K, [P1, P2, P3], quantiles=.5, weight=l, verbose=True, solver='CLARABEL')
spq
# Out:
# [autoreload of spcqe.solvers failed: Traceback (most recent call last):
#   File "/Users/bennetm/miniconda3/envs/spcqe-dev/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 273, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/bennetm/miniconda3/envs/spcqe-dev/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 471, in superreload
#     module = reload(module)
#   File "/Users/bennetm/miniconda3/envs/spcqe-dev/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/bennetm/Documents/github/spcqe/src/spcqe/solvers.py", line 4, in <module>
#     from gfosd import Problem as ProblemOSD
# ModuleNotFoundError: No module named 'gfosd'
# ]
# [autoreload of spcqe.quantiles failed: Traceback (most recent call last):
#   File "/Users/bennetm/miniconda3/envs/spcqe-dev/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 273, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/bennetm/miniconda3/envs/spcqe-dev/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 471, in superreload
#     module = reload(module)
#   File "/Users/bennetm/miniconda3/envs/spcqe-dev/lib/python3.10/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 619, in _exec
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/bennetm/Documents/github/spcqe/src/spcqe/quantiles.py", line 4, in <module>
#     from spcqe.solvers import solve_cvx, solve_osd
# ImportError: cannot import name 'solve_osd' from 'spcqe.solvers' (/Users/bennetm/Documents/github/spcqe/src/spcqe/solvers.py)
# ]
# SmoothPeriodicQuantiles(num_harmonics=3, periods=[8760, 168, 24],
#                         quantiles=array([0.5]), solver='CLARABEL', verbose=True,
#                         weight=0.1)

# %%
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# y1 = sc.fit_transform(df['RT_Demand'].to_numpy().reshape(-1, 1))
# y1 = y1.ravel()
y1 = df['RT_Demand'].to_numpy()
spq.fit(y1)
print(f"total time: {spq.fit_time:.2f} seconds")
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Aug 25 03:17:29 PM: Your problem has 128 variables, 0 constraints, and 0 parameters.
# (CVXPY) Aug 25 03:17:29 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 25 03:17:29 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 25 03:17:29 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 25 03:17:29 PM: Compiling problem (target solver=CLARABEL).
# (CVXPY) Aug 25 03:17:29 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> CLARABEL
# (CVXPY) Aug 25 03:17:29 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 25 03:17:29 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 25 03:17:29 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 25 03:17:31 PM: Applying reduction CLARABEL
# (CVXPY) Aug 25 03:17:32 PM: Finished problem compilation (took 3.143e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 25 03:17:32 PM: Invoking solver CLARABEL  to obtain a solution.
# -------------------------------------------------------------
#            Clarabel.rs v0.5.1  -  Clever Acronym
#
#                    (c) Paul Goulart
#                 University of Oxford, 2022
# -------------------------------------------------------------
#
# problem:
#   variables     = 35320
#   constraints   = 70256
#   nnz(P)        = 128
#   nnz(A)        = 9046586
#   cones (total) = 2
#     :        Zero = 1,  numel = 128
#     : Nonnegative = 1,  numel = 70128
#
# settings:
#   linear algebra: direct / qdldl, precision: 64 bit
#   max iter = 200, time limit = Inf,  max step = 0.990
#   tol_feas = 1.0e-8, tol_gap_abs = 1.0e-8, tol_gap_rel = 1.0e-8,
#   static reg : on, ϵ1 = 1.0e-8, ϵ2 = 4.9e-32
#   dynamic reg: on, ϵ = 1.0e-13, δ = 2.0e-7
#   iter refine: on, reltol = 1.0e-13, abstol = 1.0e-12,
#                max iter = 10, stop ratio = 5.0
#   equilibrate: on, min_scale = 1.0e-4, max_scale = 1.0e4
#                max iter = 10
#
# iter    pcost        dcost       gap       pres      dres      k/t        μ       step
# ---------------------------------------------------------------------------------------------
#   0  -6.5647e+03  +3.4931e+08  5.32e+04  9.72e-01  1.27e+00  1.00e+00  3.06e+05   ------
#   1  +9.1800e+06  +2.4197e+07  1.64e+00  2.81e-02  8.95e-02  1.58e+01  1.41e+04  9.54e-01
#   2  +3.6456e+06  +5.2297e+06  4.35e-01  7.07e-03  2.43e-02  4.67e+02  4.04e+03  8.17e-01
#   3  +1.3200e+06  +1.5442e+06  1.70e-01  1.81e-03  7.19e-03  2.39e+02  1.80e+03  7.42e-01
#   4  +1.1269e+06  +1.1728e+06  4.07e-02  3.89e-04  1.59e-03  4.55e+01  4.51e+02  7.67e-01
#   5  +1.0965e+06  +1.1139e+06  1.59e-02  1.49e-04  6.12e-04  1.58e+01  1.77e+02  6.49e-01
#   6  +1.0891e+06  +1.0994e+06  9.41e-03  8.79e-05  3.61e-04  8.22e+00  1.05e+02  4.83e-01
#   7  +1.0831e+06  +1.0880e+06  4.57e-03  4.25e-05  1.75e-04  3.56e+00  5.12e+01  5.70e-01
#   8  +1.0805e+06  +1.0833e+06  2.58e-03  2.39e-05  9.84e-05  1.70e+00  2.89e+01  5.30e-01
#   9  +1.0783e+06  +1.0794e+06  9.71e-04  9.00e-06  3.71e-05  5.20e-01  1.09e+01  7.04e-01
#  10  +1.0777e+06  +1.0782e+06  4.86e-04  4.50e-06  1.86e-05  1.36e-01  5.46e+00  7.81e-01
#  11  +1.0772e+06  +1.0774e+06  2.00e-04  1.85e-06  7.62e-06  5.11e-02  2.24e+00  6.37e-01
#  12  +1.0770e+06  +1.0771e+06  8.71e-05  8.07e-07  3.32e-06  1.73e-02  9.78e-01  7.05e-01
#  13  +1.0769e+06  +1.0769e+06  2.98e-05  2.76e-07  1.14e-06  4.85e-03  3.34e-01  7.61e-01
#  14  +1.0769e+06  +1.0769e+06  1.20e-05  1.11e-07  4.57e-07  1.50e-03  1.34e-01  7.78e-01
#  15  +1.0769e+06  +1.0769e+06  4.00e-06  3.71e-08  1.53e-07  4.78e-04  4.50e-02  7.09e-01
#  16  +1.0769e+06  +1.0769e+06  9.17e-07  8.50e-09  3.50e-08  9.18e-05  1.03e-02  8.82e-01
#  17  +1.0769e+06  +1.0769e+06  2.27e-07  2.10e-09  8.66e-09  2.23e-05  2.55e-03  7.73e-01
#  18  +1.0769e+06  +1.0769e+06  3.49e-08  3.23e-10  1.33e-09  3.05e-06  3.92e-04  9.34e-01
#  19  +1.0769e+06  +1.0769e+06  9.32e-09  8.63e-11  3.56e-10  8.03e-07  1.05e-04  7.79e-01
# ---------------------------------------------------------------------------------------------
# Terminated with status = Solved
# solve time = 54.092029626s
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 25 03:18:27 PM: Problem status: optimal
# (CVXPY) Aug 25 03:18:27 PM: Optimal value: 1.077e+06
# (CVXPY) Aug 25 03:18:27 PM: Compilation took 3.143e+00 seconds
# (CVXPY) Aug 25 03:18:27 PM: Solver (including time spent in interface) took 5.486e+01 seconds
# total time: 58.05 seconds

# %%
ix = 0
slc = np.s_[24 * ix:24 * (ix + 10)]
xs = df.index[slc]
plt.plot(xs, y1[slc], ls='--')
plt.plot(xs, spq.fit_quantiles[slc, :], alpha=0.5)
plt.xticks(rotation=45);

# %%
ix = 200
slc = np.s_[24 * ix:24 * (ix + 10)]
xs = df.index[slc]
plt.plot(xs, y1[slc], ls='--')
plt.plot(xs, spq.fit_quantiles[slc, :], alpha=0.5)
plt.xticks(rotation=45);

# %%
ix = 150
slc = np.s_[24 * ix:24 * (ix + 10)]
xs = df.index[slc]
saved_quantiles = np.loadtxt('quantiles_saved.txt')
plt.plot(xs, saved_quantiles[slc, 5], label='full fit')
plt.plot(xs, spq.fit_quantiles[slc, :], label='single fit')
plt.legend()
plt.title(f"{spq.quantiles[0]*100:.0f}th percentile fit, single Clarabel fit versus full MOSEK fit")
plt.xticks(rotation=45);
