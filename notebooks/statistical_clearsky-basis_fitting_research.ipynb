# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from spcqe.quantiles import SmoothPeriodicQuantiles
# PVInsight Code Imports
from solardatatools import DataHandler
from solardatatools.dataio import get_pvdaq_data

# %% [markdown]
# ### Load data table from external source
#
# For today's example, we're loading data from NREL's PVDAQ API, which is a publically available PV generatation data set.

# %%
data_frame = get_pvdaq_data(sysid=34, year=range(2011, 2015), api_key='DEMO_KEY')
# Out:
# [============================================================] 100.0% ...queries complete in 6.8 seconds

# %%
data_frame.head()
# Out:
#                      SiteID  ac_current  ac_power  ac_voltage  ambient_temp  \
# 2011-01-01 00:00:00    34.0         0.0    -200.0       284.0     -3.353332
# 2011-01-01 00:15:00    34.0         0.0    -300.0       284.0     -3.381110
# 2011-01-01 00:30:00    34.0         0.0    -300.0       284.0     -3.257777
# 2011-01-01 00:45:00    34.0         0.0    -200.0       283.0     -3.296666
# 2011-01-01 01:00:00    34.0         0.0    -300.0       284.0     -3.426110
#
#                      dc_current  dc_power  dc_voltage  inverter_error_code  \
# 2011-01-01 00:00:00         0.0    -200.0        16.0                  0.0
# 2011-01-01 00:15:00         0.0    -200.0        16.0                  0.0
# 2011-01-01 00:30:00         0.0    -200.0        16.0                  0.0
# 2011-01-01 00:45:00         0.0       0.0        15.0                  0.0
# 2011-01-01 01:00:00         0.0    -200.0        14.0                  0.0
#
# ...

# %% [markdown]
# ### Running the `DataHandler` processing pipeline

# %%
dh = DataHandler(data_frame)

# %%
dh.run_pipeline(power_col='ac_power')
# Out:
# total time: 11.15 seconds
# --------------------------------
# Breakdown
# --------------------------------
# Preprocessing              4.19s
# Cleaning                   0.24s
# Filtering/Summarizing      6.72s
#     Data quality           0.13s
#     Clear day detect       0.27s
#     Clipping detect        3.43s
#     Capacity change detect 2.88s

# %%
dh.report()
# Out:
# -----------------
# DATA SET REPORT
# -----------------
# length               4.00 years
# capacity estimate    107.10 kW
# data sampling        15 minutes
# quality score        0.96
# clearness score      0.55
# inverter clipping    False
# clipped fraction     0.00
# capacity changes     False
# data quality warning True
# time shift errors    False
# time zone errors     False

# %%
dh.plot_heatmap('filled');

# %%
data = np.copy(dh.raw_data_matrix)
msk = dh.daytime_analysis.sunup_mask_estimated
data[~msk] = 0
y = data.ravel(order='F')
sns.heatmap(data)
# Out:
# <Axes: >

# %%
P1 = int(365*24*4)
P2 = int(24*4)
K = 6
l = 0.1
spq = SmoothPeriodicQuantiles(K, [P1, P2], quantiles=.85, weight=l, take_log=False, verbose=True, solver='osd', max_cross_k=None)
spq
# Out:
# SmoothPeriodicQuantiles(num_harmonics=6, periods=[35040, 96],
#                         quantiles=array([0.85]), solver='osd', verbose=True,
#                         weight=0.1)

# %%
spq.fit(y)
# Out:
# ---------------------------------------------------------------
#               QSS: the Quadratic-Separable Solver
#                      author: Luke Volpatti
# ---------------------------------------------------------------
# problem size:                    280682 variables
# initial factorization time:      8.23e+00s
# (standard algorithm)
#
#                            ADMM solve
# ---------------------------------------------------------------
#  iter | objective | primal res | dual res |   rho   | time (s)
# ---------------------------------------------------------------
#     1 | 1.14e+03    1.04e+00     1.13e+00   [0.5  0.02]  2.11e-01
#    25 | 3.46e+03    4.49e-02     2.08e-02   [0.5  0.02]  5.09e+00
#    50 | 3.53e+03    2.53e-02     9.54e-03   [0.5  0.02]  1.02e+01
#    75 | 3.55e+03    1.58e-02     5.92e-03   [0.5  0.02]  1.53e+01
#   100 | 3.56e+03    1.25e-02     5.39e-03   [0.5  0.02]  2.04e+01
#   125 | 3.57e+03    1.26e-02     3.21e-03   [0.5  0.02]  2.55e+01
# ...

# %%
ix = 260
slc = np.s_[24 * 4 * ix:24 * 4 * (ix + 3)]
xs = data_frame.index[slc]
plt.plot(xs, y[slc], ls='--')
plt.plot(xs, spq.fit_quantiles[slc], alpha=0.5)
plt.ylim(-10, np.nanmax(y)*1.1)
plt.xticks(rotation=45);

# %%
plt.plot(xs, np.log(spq.fit_quantiles[slc]), alpha=0.5)
# Out:
# /var/folders/j_/td27y9gx7rb9hpm_8cdzbzxc5b9m8z/T/ipykernel_79195/1577072111.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(xs, np.log(spq.fit_quantiles[slc]), alpha=0.5)

# %%
from scipy.linalg import svd

# %%
U, S, Vh = svd(dh.filled_data_matrix, full_matrices=False)

# %%
sns.heatmap(U, cmap='plasma');

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(8, 8))
for ix in range(7):
    i = ix % 4
    j = ix // 4
    axes[i, j].plot(U.T[ix]);
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.heatmap(Vh, cmap='plasma', ax=plt.gca());

# %%
plt.plot(Vh[8]);

# %%
np.sqrt(np.sum(np.power(dh.filled_data_matrix,2)))
# Out:
# 17122328.408133414

# %%
scaled_S = S
plt.stem(scaled_S[:40], label='singular values of daily signals')
plt.axhline(scaled_S[0] * 1e-1, ls='--', color='pink', label='1 order of magnitude')
plt.axhline(scaled_S[0] * (10**-1.5), ls='--', color='red', label='1.5 orders of magnitude')
plt.axhline(scaled_S[0] * 1e-2, ls='--', color='orange', label='2 orders of magnitude')
plt.yscale('log')
plt.legend();

# %%
scaled_S = 96/np.sqrt(S)
plt.stem(scaled_S[:40], label='singular values of daily signals')
plt.yscale('log')
plt.legend();

# %%
sns.heatmap((U[:, :7] @ np.diag(S[:7]) @ Vh[:7, :6]));

# %%
d = 1070
max_s = 9
days = np.s_[d:d+3]
plt.plot(dh.filled_data_matrix[:, days].ravel(order='F'), label='measured data')
plt.plot((U[:, :max_s] @ np.diag(S[:max_s]) @ Vh[:max_s, days]).ravel(order='F'), label='truncated SVD')
plt.legend();

# %%
D = dh.filled_data_matrix.copy()
D_max = np.max(D)
mu = np.average(D/D_max, axis=1)
D_tilde = (D.T/D_max - mu).T
plt.plot(mu);

# %%
plt.plot(D_tilde[:, 250]);

# %%
sns.heatmap(D_tilde @ D_tilde.T, cmap='plasma')
# Out:
# <Axes: >

# %%
u, d = np.linalg.eigh(D_tilde @ D_tilde.T)
plt.stem(-np.sort(-u))
plt.yscale('log')

# %%
sns.heatmap(d)
# Out:
# <Axes: >

# %%
plt.stem(1/u[-7:])
plt.yscale('log')

# %%
from spcqe.functions import make_basis_matrix

# %%
fourier_basis = make_basis_matrix(12, 96, 96)[:, 2:]

# %%
sns.heatmap(fourier_basis, cmap='plasma')
# Out:
# <Axes: >

# %%
cvx.diag?
# Out:
# Signature: cvx.diag(expr) -> Union[ForwardRef('diag_mat'), ForwardRef('diag_vec')]
# Docstring:
# Extracts the diagonal from a matrix or makes a vector a diagonal matrix.
#
# Parameters
# ----------
# expr : Expression or numeric constant
#     A vector or square matrix.
#
# Returns
# -------
# Expression
#     An Expression representing the diagonal vector/matrix.
# File:      ~/miniconda3/envs/spcqe-dev/lib/python3.10/site-packages/cvxpy/atoms/affine/diag.py
# Type:      function

# %%
import cvxpy as cvx

# X = cvx.Variable((foo.shape[1], D.shape[1]))
# loss = cvx.sum_squares(D_tilde - foo @ X)
x = cvx.Variable(foo.shape[1])
X = cvx.diag(x)
model = foo @ X @ foo.T
loss = cvx.sum_squares(D_tilde @ D_tilde.T - model)
problem = cvx.Problem(cvx.Minimize(loss))
problem.solve(verbose=True)
# Out:
# ...
#                                      CVXPY
#                                      v1.3.2
# ...
# (CVXPY) Aug 31 10:44:18 AM: Your problem has 24 variables, 0 constraints, and 0 parameters.
# (CVXPY) Aug 31 10:44:18 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 31 10:44:18 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 31 10:44:18 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 31 10:44:18 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Aug 31 10:44:18 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Aug 31 10:44:18 AM: Applying reduction CvxAttr2Constr
# ...

# %%
plt.plot(x.value, marker='.', label='fourier basis weightings')
plt.plot(-np.sort(-u)[:24], marker='.', label='eiganvalue decomposition')
plt.legend()
plt.yscale('log');

# %%
plt.stem(-np.sort(-u)[:24])
# Out:
# <StemContainer object of 3 artists>

# %%
plt.scatter(x.value, -np.sort(-u)[:24], marker='.', label='eiganvalue decomposition')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('fourier weights')
plt.ylabel('eigenvalues');
