# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from spcqe.functions_old import fit_quantiles3

# %%
def process_excel_file(file_name, year):
    # Check if the year is a leap year
    is_leap_year = (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)
    
    # Define the start and end of your time range
    start = pd.Timestamp(f'{year}-01-01 00:00:00')
    end = pd.Timestamp(f'{year}-12-31 23:00:00')
    
    # Create an hourly time index between start and end
    time_index = pd.date_range(start, end, freq='H')
    
    # Read the Excel file and select columns
    df = pd.read_excel(file_name, sheet_name='RI', usecols=['RT_Demand', 'Dry_Bulb', 'RT_LMP'])
    
    # Assign your new time index to your dataframe
    df.index = time_index
    
    # Convert columns to numpy arrays
    y1 = df['RT_Demand'].to_numpy()
    y2 = df['Dry_Bulb'].to_numpy()
    y3 = df['RT_LMP'].to_numpy()
    
    return y1, y2, y3

years = [2019, 2020, 2021, 2022]

y1_list, y2_list, y3_list = [], [], []

for year in years:
    file_name =  Path() / 'fixtures' / f'{year}_smd_hourly.xlsx'  # Assuming your file name format
    y1, y2, y3 = process_excel_file(file_name, year)
    y1_list.append(y1)
    y2_list.append(y2)
    y3_list.append(y3)

# Stack the arrays in each list column-wise
y1 = np.hstack(y1_list)
y2 = np.hstack(y2_list)
y3 = np.hstack(y3_list)

# %%
percentiles = [2,10,20,30,40,50,60,70,80,90,98]
P1 = int(365*24)
P2 = int(7*24)
P3 = int(24)
K = 3
l = 0.1
Quantiles = fit_quantiles3(y1, K, P1, P2, P3, l, percentiles)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Aug 23 04:46:54 PM: Your problem has 1408 variables, 1 constraints, and 0 parameters.
# (CVXPY) Aug 23 04:46:54 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Aug 23 04:46:54 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 23 04:46:54 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 23 04:46:54 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 23 04:46:54 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 23 04:46:54 PM: Applying reduction Dcp2Cone
# (CVXPY) Aug 23 04:46:54 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 23 04:46:54 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 23 04:47:40 PM: Applying reduction MOSEK
# (CVXPY) Aug 23 04:48:16 PM: Finished problem compilation (took 8.245e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 23 04:48:16 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Aug 23 04:49:09 PM: MOSEK warning 500 (MSK_RES_WRN_LICENSE_EXPIRE): The license expires in 3 days.
# (CVXPY) Aug 23 04:49:09 PM: MOSEK warning 500 (MSK_RES_WRN_LICENSE_EXPIRE): The license expires in 3 days.
# (CVXPY) Aug 23 04:49:09 PM: Problem
# (CVXPY) Aug 23 04:49:09 PM:   Name                   :
# (CVXPY) Aug 23 04:49:09 PM:   Objective sense        : maximize
# (CVXPY) Aug 23 04:49:09 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 23 04:49:09 PM:   Constraints            : 387113
# (CVXPY) Aug 23 04:49:09 PM:   Affine conic cons.     : 0
# (CVXPY) Aug 23 04:49:09 PM:   Disjunctive cons.      : 0
# (CVXPY) Aug 23 04:49:09 PM:   Cones                  : 1
# (CVXPY) Aug 23 04:49:09 PM:   Scalar variables       : 1123458
# (CVXPY) Aug 23 04:49:09 PM:   Matrix variables       : 0
# (CVXPY) Aug 23 04:49:09 PM:   Integer variables      : 0
# (CVXPY) Aug 23 04:49:09 PM:
# (CVXPY) Aug 23 04:49:09 PM: Optimizer started.
# (CVXPY) Aug 23 04:49:17 PM: Presolve started.
# (CVXPY) Aug 23 04:49:18 PM: Linear dependency checker started.
# (CVXPY) Aug 23 04:49:19 PM: Linear dependency checker terminated.
# (CVXPY) Aug 23 04:49:19 PM: Eliminator started.
# (CVXPY) Aug 23 04:49:29 PM: Freed constraints in eliminator : 293216
# (CVXPY) Aug 23 04:49:29 PM: Eliminator terminated.
# (CVXPY) Aug 23 04:49:31 PM: Eliminator started.
# (CVXPY) Aug 23 04:49:36 PM: Freed constraints in eliminator : 0
# (CVXPY) Aug 23 04:49:36 PM: Eliminator terminated.
# (CVXPY) Aug 23 04:49:36 PM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY)
# (CVXPY) Aug 23 04:50:46 PM: 53  1.2e-03  9.2e-04  1.1e-08  9.99e-01   7.646375043e+06   7.646375042e+06   1.6e-07  96.56
# (CVXPY) Aug 23 04:50:47 PM: 54  9.8e-04  7.3e-04  6.4e-09  1.00e+00   7.646656135e+06   7.646656134e+06   1.3e-07  97.75
# (CVXPY) Aug 23 04:50:48 PM: 55  1.6e-04  1.2e-04  2.5e-10  1.00e+00   7.647600802e+06   7.647600802e+06   2.1e-08  99.26
# (CVXPY) Aug 23 04:50:49 PM: 56  8.3e-05  6.2e-05  2.9e-09  1.00e+00   7.647687158e+06   7.647687158e+06   1.1e-08  100.22
# (CVXPY) Aug 23 04:50:52 PM: 57  3.6e-05  2.7e-05  2.9e-09  1.00e+00   7.647740643e+06   7.647740643e+06   4.8e-09  102.60
# (CVXPY) Aug 23 04:50:53 PM: 58  1.3e-05  1.0e-05  5.6e-10  1.00e+00   7.647767028e+06   7.647767028e+06   1.8e-09  103.80
# (CVXPY) Aug 23 04:50:54 PM: 59  5.4e-06  4.1e-06  1.1e-10  1.00e+00   7.647776314e+06   7.647776314e+06   7.2e-10  104.70
# (CVXPY) Aug 23 04:50:55 PM: 60  3.4e-06  2.6e-06  3.5e-10  1.00e+00   7.647778602e+06   7.647778602e+06   4.5e-10  106.41
# (CVXPY) Aug 23 04:50:56 PM: 61  7.5e-07  5.6e-07  6.9e-10  1.00e+00   7.647781683e+06   7.647781683e+06   9.9e-11  107.36
# (CVXPY) Aug 23 04:50:57 PM: Optimizer terminated. Time: 108.14
# (CVXPY) Aug 23 04:50:57 PM:
# (CVXPY) Aug 23 04:50:57 PM: Interior-point solution summary
# (CVXPY) Aug 23 04:50:57 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Aug 23 04:50:57 PM:   Solution status : OPTIMAL
# (CVXPY) Aug 23 04:50:58 PM:   Primal.  obj: 7.6477816833e+06    nrm: 2e+04    Viol.
# (CVXPY) Aug 23 04:50:58 PM:   con: 2e-04
# (CVXPY) Aug 23 04:50:58 PM:   var: 3e-08
# (CVXPY) Aug 23 04:50:58 PM:   cones: 0e+00
# (CVXPY) Aug 23 04:50:58 PM:
# (CVXPY) Aug 23 04:50:58 PM:   Dual.    obj: 7.6477816833e+06    nrm: 9e+03    Viol.
# (CVXPY) Aug 23 04:50:58 PM:   con: 0e+00
# (CVXPY) Aug 23 04:50:58 PM:   var: 3e-05
# (CVXPY) Aug 23 04:50:58 PM:   cones: 0e+00
# (CVXPY) Aug 23 04:50:58 PM:
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 23 04:50:58 PM: Problem status: optimal
# (CVXPY) Aug 23 04:50:58 PM: Optimal value: 7.648e+06
# (CVXPY) Aug 23 04:50:58 PM: Compilation took 8.245e+01 seconds
# (CVXPY) Aug 23 04:50:58 PM: Solver (including time spent in interface) took 1.615e+02 seconds

# %%
Quantiles.shape
# Out:
# (35064, 11)

# %%
ix = 0
plt.plot(y1[24 * ix:24 * (ix + 10)], ls='--')
plt.plot(Quantiles[24 * ix:24 * (ix + 10), :], alpha=0.5);

# %%
ix = 200
plt.plot(y1[24 * ix:24 * (ix + 10)], ls='--')
plt.plot(Quantiles[24 * ix:24 * (ix + 10), :], alpha=0.5);

# %%
np.savetxt('quantiles_saved.txt', Quantiles)
